# %% [raw]
# # 🤖 TavilyCrawl Tutorial: Intelligent Documentation Discovery
#
# > **📚 Part of the LangChain Course: Building AI Agents & RAG Apps**
# > [🎓 Get the full course](https://www.udemy.com/course/langchain/?referralCode=D981B8213164A3EA91AC)
#
# This notebook demonstrates the power of **TavilyCrawl** - Tavily's most intelligent web crawling tool that:
# - 🕷️ **Crawls intelligently** using graph-based traversal with parallel exploration
# - 🧠 **Understands instructions** and filters content based on your specific needs
# - 🎯 **Finds exactly what you need** without manual filtering or post-processing
# - ⚡ **Processes hundreds of pages** efficiently with built-in content extraction
#
# **Perfect for targeted documentation discovery, research, and intelligent content collection!** 🚀
#
# ---

# %% [raw]
# ## 📦 Setup & Installation
#
# First, let's install the required packages and set up our environment.

# %%
# Install required packages
# %pip install langchain-tavily certifi

# For pretty printing and visualization
# %pip install rich pandas
# Out:
# Collecting langchain-tavily
#   Downloading langchain_tavily-0.2.17-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: certifi in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (2026.2.25)
# Collecting aiohttp<4.0.0,>=3.11.14 (from langchain-tavily)
#   Downloading aiohttp-3.13.3-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Collecting langchain<2.0.0,>=0.3.20 (from langchain-tavily)
#   Downloading langchain-1.2.12-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.15 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langchain-tavily) (1.2.17)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langchain-tavily) (2.32.5)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading multidict-6.7.1-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.11.14->langchain-tavily)
#   Downloading yarl-1.23.0-cp312-cp312-win_amd64.whl.metadata (82 kB)
# Collecting langgraph<1.2.0,>=1.1.1 (from langchain<2.0.0,>=0.3.20->langchain-tavily)
#   Downloading langgraph-1.1.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langchain<2.0.0,>=0.3.20->langchain-tavily) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (0.7.14)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain<2.0.0,>=0.3.20->langchain-tavily) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain<2.0.0,>=0.3.20->langchain-tavily) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain<2.0.0,>=0.3.20->langchain-tavily) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain<2.0.0,>=0.3.20->langchain-tavily) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain<2.0.0,>=0.3.20->langchain-tavily) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain<2.0.0,>=0.3.20->langchain-tavily) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain<2.0.0,>=0.3.20->langchain-tavily) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (0.25.0)
# Requirement already satisfied: anyio in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain<2.0.0,>=0.3.20->langchain-tavily) (4.12.1)
# Requirement already satisfied: httpcore==1.* in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain<2.0.0,>=0.3.20->langchain-tavily) (1.0.9)
# Requirement already satisfied: idna in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain<2.0.0,>=0.3.20->langchain-tavily) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain<2.0.0,>=0.3.20->langchain-tavily) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.20->langchain-tavily) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.20->langchain-tavily) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.20->langchain-tavily) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (2.6.3)
# Downloading langchain_tavily-0.2.17-py3-none-any.whl (30 kB)
# Downloading aiohttp-3.13.3-cp312-cp312-win_amd64.whl (455 kB)
# Downloading langchain-1.2.12-py3-none-any.whl (112 kB)
# Downloading langgraph-1.1.2-py3-none-any.whl (167 kB)
# Downloading multidict-6.7.1-cp312-cp312-win_amd64.whl (46 kB)
# Downloading yarl-1.23.0-cp312-cp312-win_amd64.whl (87 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl (44 kB)
# Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl (41 kB)
# Installing collected packages: propcache, multidict, frozenlist, attrs, aiohappyeyeballs, yarl, aiosignal, aiohttp, langgraph, langchain, langchain-tavily
#
#    --- ------------------------------------  1/11 [multidict]
#    ------- --------------------------------  2/11 [frozenlist]
#    ------- --------------------------------  2/11 [frozenlist]
#    ---------- -----------------------------  3/11 [attrs]
#    -------------- -------------------------  4/11 [aiohappyeyeballs]
#    -------------- -------------------------  4/11 [aiohappyeyeballs]
#    ------------------ ---------------------  5/11 [yarl]
#    --------------------- ------------------  6/11 [aiosignal]
#    ------------------------- --------------  7/11 [aiohttp]
#    ------------------------- --------------  7/11 [aiohttp]
#    ------------------------- --------------  7/11 [aiohttp]
#    ------------------------- --------------  7/11 [aiohttp]
#    ------------------------- --------------  7/11 [aiohttp]
#   Attempting uninstall: langgraph
#    ------------------------- --------------  7/11 [aiohttp]
#     Found existing installation: langgraph 1.0.10
#    ------------------------- --------------  7/11 [aiohttp]
#    ----------------------------- ----------  8/11 [langgraph]
#     Uninstalling langgraph-1.0.10:
#    ----------------------------- ----------  8/11 [langgraph]
#       Successfully uninstalled langgraph-1.0.10
#    ----------------------------- ----------  8/11 [langgraph]
#    ----------------------------- ----------  8/11 [langgraph]
#    ----------------------------- ----------  8/11 [langgraph]
#    ----------------------------- ----------  8/11 [langgraph]
#    ----------------------------- ----------  8/11 [langgraph]
#    ----------------------------- ----------  8/11 [langgraph]
#    ----------------------------- ----------  8/11 [langgraph]
#    ----------------------------- ----------  8/11 [langgraph]
#    ----------------------------- ----------  8/11 [langgraph]
#    ----------------------------- ----------  8/11 [langgraph]
#    -------------------------------- -------  9/11 [langchain]
#    -------------------------------- -------  9/11 [langchain]
#    -------------------------------- -------  9/11 [langchain]
#    -------------------------------- -------  9/11 [langchain]
#    -------------------------------- -------  9/11 [langchain]
#    ------------------------------------ --- 10/11 [langchain-tavily]
#    ---------------------------------------- 11/11 [langchain-tavily]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 attrs-25.4.0 frozenlist-1.8.0 langchain-1.2.12 langchain-tavily-0.2.17 langgraph-1.1.2 multidict-6.7.1 propcache-0.4.1 yarl-1.23.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting rich
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting pandas
#   Downloading pandas-3.0.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting markdown-it-py>=2.2.0 (from rich)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from rich) (2.19.2)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.3-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in c:\Users\wuqiu\anaconda3\envs\LangGraph\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Downloading pandas-3.0.1-cp312-cp312-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 1.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.5/9.7 MB 1.5 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/9.7 MB 799.2 kB/s eta 0:00:12
#    ---- ----------------------------------- 1.0/9.7 MB 949.8 kB/s eta 0:00:10
#    ---- ----------------------------------- 1.0/9.7 MB 949.8 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.3/9.7 MB 945.5 kB/s eta 0:00:09
#    ----- ---------------------------------- 1.3/9.7 MB 945.5 kB/s eta 0:00:09
#    ------ --------------------------------- 1.6/9.7 MB 839.1 kB/s eta 0:00:10
#    ------- -------------------------------- 1.8/9.7 MB 838.9 kB/s eta 0:00:10
#    ------- -------------------------------- 1.8/9.7 MB 838.9 kB/s eta 0:00:10
#    -------- ------------------------------- 2.1/9.7 MB 851.1 kB/s eta 0:00:09
#    --------- ------------------------------ 2.4/9.7 MB 865.9 kB/s eta 0:00:09
#    ---------- ----------------------------- 2.6/9.7 MB 878.0 kB/s eta 0:00:09
#    ---------- ----------------------------- 2.6/9.7 MB 878.0 kB/s eta 0:00:09
#    ----------- ---------------------------- 2.9/9.7 MB 873.8 kB/s eta 0:00:08
#    ------------ --------------------------- 3.1/9.7 MB 870.6 kB/s eta 0:00:08
#    ------------ --------------------------- 3.1/9.7 MB 870.6 kB/s eta 0:00:08
#    ------------- -------------------------- 3.4/9.7 MB 860.4 kB/s eta 0:00:08
#    --------------- ------------------------ 3.7/9.7 MB 865.6 kB/s eta 0:00:08
#    --------------- ------------------------ 3.7/9.7 MB 865.6 kB/s eta 0:00:08
#    ---------------- ----------------------- 3.9/9.7 MB 848.0 kB/s eta 0:00:07
#    ----------------- ---------------------- 4.2/9.7 MB 841.6 kB/s eta 0:00:07
#    ----------------- ---------------------- 4.2/9.7 MB 841.6 kB/s eta 0:00:07
#    ------------------ --------------------- 4.5/9.7 MB 836.4 kB/s eta 0:00:07
#    ------------------- -------------------- 4.7/9.7 MB 846.4 kB/s eta 0:00:06
#    -------------------- ------------------- 5.0/9.7 MB 855.6 kB/s eta 0:00:06
#    -------------------- ------------------- 5.0/9.7 MB 855.6 kB/s eta 0:00:06
#    --------------------- ------------------ 5.2/9.7 MB 850.1 kB/s eta 0:00:06
#    ---------------------- ----------------- 5.5/9.7 MB 851.7 kB/s eta 0:00:05
#    ---------------------- ----------------- 5.5/9.7 MB 851.7 kB/s eta 0:00:05
#    ----------------------- ---------------- 5.8/9.7 MB 851.1 kB/s eta 0:00:05
#    ------------------------ --------------- 6.0/9.7 MB 844.6 kB/s eta 0:00:05
#    ------------------------ --------------- 6.0/9.7 MB 844.6 kB/s eta 0:00:05
#    ------------------------- -------------- 6.3/9.7 MB 844.4 kB/s eta 0:00:05
#    ------------------------- -------------- 6.3/9.7 MB 844.4 kB/s eta 0:00:05
#    -------------------------- ------------- 6.6/9.7 MB 838.9 kB/s eta 0:00:04
#    --------------------------- ------------ 6.8/9.7 MB 842.3 kB/s eta 0:00:04
#    ----------------------------- ---------- 7.1/9.7 MB 847.0 kB/s eta 0:00:04
#    ------------------------------ --------- 7.3/9.7 MB 849.9 kB/s eta 0:00:03
#    ------------------------------ --------- 7.3/9.7 MB 849.9 kB/s eta 0:00:03
#    ------------------------------- -------- 7.6/9.7 MB 849.5 kB/s eta 0:00:03
#    -------------------------------- ------- 7.9/9.7 MB 850.6 kB/s eta 0:00:03
#    -------------------------------- ------- 7.9/9.7 MB 850.6 kB/s eta 0:00:03
#    --------------------------------- ------ 8.1/9.7 MB 848.8 kB/s eta 0:00:02
#    ---------------------------------- ----- 8.4/9.7 MB 849.9 kB/s eta 0:00:02
#    ---------------------------------- ----- 8.4/9.7 MB 849.9 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.7/9.7 MB 848.2 kB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.7 MB 847.9 kB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.7 MB 847.9 kB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.7 MB 835.2 kB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.7 MB 835.2 kB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.7 MB 831.8 kB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.7 MB 831.8 kB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 822.1 kB/s  0:00:11
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading numpy-2.4.3-cp312-cp312-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 932.9 kB/s eta 0:00:13
#    -- ------------------------------------- 0.8/12.3 MB 1.0 MB/s eta 0:00:12
#    -- ------------------------------------- 0.8/12.3 MB 1.0 MB/s eta 0:00:12
#    --- ------------------------------------ 1.0/12.3 MB 931.8 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.3/12.3 MB 919.0 kB/s eta 0:00:12
#    ---- ----------------------------------- 1.3/12.3 MB 919.0 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.6/12.3 MB 902.1 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.8/12.3 MB 890.6 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.8/12.3 MB 890.6 kB/s eta 0:00:12
#    ------ --------------------------------- 2.1/12.3 MB 883.1 kB/s eta 0:00:12
#    ------- -------------------------------- 2.4/12.3 MB 871.6 kB/s eta 0:00:12
#    -------- ------------------------------- 2.6/12.3 MB 883.0 kB/s eta 0:00:11
#    -------- ------------------------------- 2.6/12.3 MB 883.0 kB/s eta 0:00:11
#    --------- ------------------------------ 2.9/12.3 MB 873.8 kB/s eta 0:00:11
#    ---------- ----------------------------- 3.1/12.3 MB 866.5 kB/s eta 0:00:11
#    ---------- ----------------------------- 3.1/12.3 MB 866.5 kB/s eta 0:00:11
#    ----------- ---------------------------- 3.4/12.3 MB 871.6 kB/s eta 0:00:11
#    ----------- ---------------------------- 3.7/12.3 MB 865.4 kB/s eta 0:00:10
#    ----------- ---------------------------- 3.7/12.3 MB 865.4 kB/s eta 0:00:10
#    ------------ --------------------------- 3.9/12.3 MB 866.8 kB/s eta 0:00:10
#    ------------- -------------------------- 4.2/12.3 MB 861.7 kB/s eta 0:00:10
#    ------------- -------------------------- 4.2/12.3 MB 861.7 kB/s eta 0:00:10
#    -------------- ------------------------- 4.5/12.3 MB 863.2 kB/s eta 0:00:10
#    --------------- ------------------------ 4.7/12.3 MB 861.6 kB/s eta 0:00:09
#    ---------------- ----------------------- 5.0/12.3 MB 860.4 kB/s eta 0:00:09
#    ---------------- ----------------------- 5.0/12.3 MB 860.4 kB/s eta 0:00:09
#    ----------------- ---------------------- 5.2/12.3 MB 856.8 kB/s eta 0:00:09
#    ----------------- ---------------------- 5.5/12.3 MB 858.2 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.5/12.3 MB 858.2 kB/s eta 0:00:08
#    ------------------ --------------------- 5.8/12.3 MB 857.2 kB/s eta 0:00:08
#    ------------------- -------------------- 6.0/12.3 MB 854.4 kB/s eta 0:00:08
#    ------------------- -------------------- 6.0/12.3 MB 854.4 kB/s eta 0:00:08
#    -------------------- ------------------- 6.3/12.3 MB 849.9 kB/s eta 0:00:08
#    --------------------- ------------------ 6.6/12.3 MB 854.9 kB/s eta 0:00:07
#    --------------------- ------------------ 6.6/12.3 MB 854.9 kB/s eta 0:00:07
#    ---------------------- ----------------- 6.8/12.3 MB 856.0 kB/s eta 0:00:07
#    ---------------------- ----------------- 7.1/12.3 MB 853.7 kB/s eta 0:00:07
#    ---------------------- ----------------- 7.1/12.3 MB 853.7 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.3/12.3 MB 849.9 kB/s eta 0:00:06
#    ------------------------ --------------- 7.6/12.3 MB 852.6 kB/s eta 0:00:06
#    ------------------------ --------------- 7.6/12.3 MB 852.6 kB/s eta 0:00:06
#    ------------------------- -------------- 7.9/12.3 MB 850.5 kB/s eta 0:00:06
#    -------------------------- ------------- 8.1/12.3 MB 848.7 kB/s eta 0:00:05
#    -------------------------- ------------- 8.1/12.3 MB 848.7 kB/s eta 0:00:05
#    --------------------------- ------------ 8.4/12.3 MB 852.6 kB/s eta 0:00:05
#    ---------------------------- ----------- 8.7/12.3 MB 849.5 kB/s eta 0:00:05
#    ---------------------------- ----------- 8.7/12.3 MB 849.5 kB/s eta 0:00:05
#    ---------------------------- ----------- 8.9/12.3 MB 847.9 kB/s eta 0:00:05
#    ----------------------------- ---------- 9.2/12.3 MB 842.6 kB/s eta 0:00:04
#    ----------------------------- ---------- 9.2/12.3 MB 842.6 kB/s eta 0:00:04
#    ------------------------------ --------- 9.4/12.3 MB 843.7 kB/s eta 0:00:04
#    ------------------------------- -------- 9.7/12.3 MB 845.9 kB/s eta 0:00:04
#    -------------------------------- ------- 10.0/12.3 MB 850.4 kB/s eta 0:00:03
#    -------------------------------- ------- 10.0/12.3 MB 850.4 kB/s eta 0:00:03
#    --------------------------------- ------ 10.2/12.3 MB 847.8 kB/s eta 0:00:03
#    --------------------------------- ------ 10.2/12.3 MB 847.8 kB/s eta 0:00:03
#    ---------------------------------- ----- 10.5/12.3 MB 837.8 kB/s eta 0:00:03
#    ---------------------------------- ----- 10.5/12.3 MB 837.8 kB/s eta 0:00:03
#    ---------------------------------- ----- 10.7/12.3 MB 834.7 kB/s eta 0:00:02
#    ----------------------------------- ---- 11.0/12.3 MB 833.8 kB/s eta 0:00:02
#    ----------------------------------- ---- 11.0/12.3 MB 833.8 kB/s eta 0:00:02
#    ------------------------------------ --- 11.3/12.3 MB 836.9 kB/s eta 0:00:02
#    ------------------------------------- -- 11.5/12.3 MB 837.9 kB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 840.8 kB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 842.6 kB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 842.6 kB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 842.6 kB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 827.7 kB/s  0:00:14
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, numpy, mdurl, pandas, markdown-it-py, rich
#
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------ --------------------------------- 1/6 [numpy]
#    ------------- -------------------------- 2/6 [mdurl]
#    ------------- -------------------------- 2/6 [mdurl]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------------- ------------- 4/6 [markdown-it-py]
#    -------------------------- ------------- 4/6 [markdown-it-py]
#    -------------------------- ------------- 4/6 [markdown-it-py]
#    -------------------------- ------------- 4/6 [markdown-it-py]
#    -------------------------- ------------- 4/6 [markdown-it-py]
#    --------------------------------- ------ 5/6 [rich]
#    --------------------------------- ------ 5/6 [rich]
#    --------------------------------- ------ 5/6 [rich]
#    --------------------------------- ------ 5/6 [rich]
#    --------------------------------- ------ 5/6 [rich]
#    --------------------------------- ------ 5/6 [rich]
#    --------------------------------- ------ 5/6 [rich]
#    --------------------------------- ------ 5/6 [rich]
#    --------------------------------- ------ 5/6 [rich]
#    ---------------------------------------- 6/6 [rich]
#
# Successfully installed markdown-it-py-4.0.0 mdurl-0.1.2 numpy-2.4.3 pandas-3.0.1 rich-14.3.3 tzdata-2025.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\wuqiu\anaconda3\envs\LangGraph\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'c:\Users\wuqiu\anaconda3\envs\LangGraph\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import os
import ssl
from typing import Any, Dict, List

import certifi
from langchain_tavily import TavilyCrawl
from rich.console import Console
from rich.panel import Panel
from rich.table import Table

# Configure SSL context
ssl_context = ssl.create_default_context(cafile=certifi.where())
os.environ["SSL_CERT_FILE"] = certifi.where()
os.environ["REQUESTS_CA_BUNDLE"] = certifi.where()

# Initialize rich console for pretty printing
console = Console()

print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %% [raw]
# ## 🔑 API Key Setup
#
# You'll need a Tavily API key to use TavilyCrawl. Get yours at [tavily.com](https://app.tavily.com/home).
#
# Set environment variable `TAVILY_API_KEY`

# %%
# Set directly (uncomment and add your key)
# tavily_api_key = "your_tavily_api_key_here"

os.environ["TAVILY_API_KEY"] = "your_tavily_api_key_here"

# %% [raw]
# ## 🤖 What is TavilyCrawl?
#
# TavilyCrawl is Tavily's most advanced crawling tool that goes beyond simple URL discovery. Here's what makes it special:
#
# ### 🧠 **Intelligent Understanding**
# - Takes natural language instructions
# - Understands context and intent
# - Filters content based on your specific needs
#
# ### 🕷️ **Advanced Crawling**
# - Graph-based website traversal
# - Parallel exploration of hundreds of paths
# - Built-in content extraction and cleaning
#
# ### 🎯 **Smart Filtering**
# - Only returns relevant content
# - Eliminates manual post-processing
# - Saves time and API calls
#
# Let's see it in action!

# %%
# Initialize TavilyCrawl
tavily_crawl = TavilyCrawl()

print("✅ TavilyCrawl initialized successfully!")
# Out:
# ✅ TavilyCrawl initialized successfully!

# %% [raw]
# ## 🎯 Demo 1: TavilyCrawl Without Instructions
#
# Let's first see what happens when we use TavilyCrawl without any specific instructions. This will show us the baseline behavior.

# %%
# Basic TavilyCrawl without instructions
target_url = "https://python.langchain.com/"

console.print(Panel.fit(
    f"🎯 **Target**: {target_url}\n📋 **Instructions**: None (baseline crawl)",
    title="Basic Crawl Configuration",
    border_style="yellow"
))

console.print("🔄 Running TavilyCrawl without instructions...", style="bold yellow")

# Basic crawl without instructions
basic_result = tavily_crawl.invoke({
    "url": target_url,
    "max_depth": 3,
    "extract_depth": "advanced"
})

basic_results = basic_result.get("results", [])
console.print(f"✅ Basic crawl completed! Found {len(basic_results)} pages", style="bold green")

# Show what we got without instructions
console.print(f"\n📊 **Without Instructions**: TavilyCrawl returned {len(basic_results)} pages", style="bold yellow")
console.print("   📄 Mix of all content types (chains, prompts, agents, guides, etc.)")
console.print("   🔍 No filtering - everything from the crawled sections")
console.print("   ⚠️  Requires manual work to find what you actually need")
# Out:
# ╭───────── Basic Crawl Configuration ──────────╮
# │ 🎯 **Target**: https://python.langchain.com/ │
# │ 📋 **Instructions**: None (baseline crawl)   │
# ╰──────────────────────────────────────────────╯
# 🔄 Running TavilyCrawl without instructions...
# ✅ Basic crawl completed! Found 0 pages
# 📊 **Without Instructions**: TavilyCrawl returned 0 pages
#    📄 Mix of all content types (chains, prompts, agents, guides, etc.)
#    🔍 No filtering - everything from the crawled sections
#    ⚠️  Requires manual work to find what you actually need

# %%
# Let's look at what the basic crawl found
console.print("\n📋 **Sample Results from Basic Crawl (no filtering):**\n", style="bold yellow")

for i, result in enumerate(basic_results[:3], 1):  # Show first 3 results
    title = result.get("title", "Untitled")
    url = result.get("url", "No URL")
    content = result.get("raw_content", "No content")[:150] + "..."
    
    panel_content = f"""
🔗 **URL**: {url}

📖 **Content Preview**:
{content}
    """.strip()
    
    console.print(Panel(
        panel_content,
        title=f"📄 {i}. {title}",
        border_style="yellow"
    ))
    print()

console.print(f"... and {len(basic_results) - 3} more mixed results", style="italic yellow")
console.print("🔍 **Notice**: These are mixed content types - not specifically about agents!", style="bold yellow")
# Out:
# 📋 **Sample Results from Basic Crawl (no filtering):**
# ... and -3 more mixed results
# 🔍 **Notice**: These are mixed content types - not specifically about agents!

# %% [raw]
# ## 🎯 Demo 2: TavilyCrawl WITH Instructions - The Magic!
#
# Now let's see the real power of TavilyCrawl! By adding simple instructions, we can get exactly what we need without any manual filtering.
#
# ### The Problem We Just Saw:
# - Demo 1 returned everything (all content types mixed together)
# - We'd need to manually filter through all results
# - No way to target specific content
#
# ### The TavilyCrawl Solution:
# - Add simple natural language instructions
# - Let AI do the intelligent filtering
# - Get exactly what we need automatically!

# %%
# Now let's add intelligent instructions to the same target
instructions = "Find and extract content from pages specifically related to agents"

console.print(Panel.fit(
    f"🎯 **Target**: {target_url} (same as Demo 1)\n📋 **Instructions**: {instructions}",
    title="Intelligent Crawl Configuration", 
    border_style="green"
))
# Out:
# ╭──────────────────────────── Intelligent Crawl Configuration ────────────────────────────╮
# │ 🎯 **Target**: https://python.langchain.com/ (same as Demo 1)                           │
# │ 📋 **Instructions**: Find and extract content from pages specifically related to agents │
# ╰─────────────────────────────────────────────────────────────────────────────────────────╯

# %%
# Execute the intelligent crawl - this demonstrates TavilyCrawl's power!
console.print("🚀 Starting intelligent crawl with instructions...", style="bold blue")
console.print("Watch how instructions transform the results!", style="italic")

# Use TavilyCrawl with instructions
crawl_result = tavily_crawl.invoke({
    "url": target_url,
    "instructions": instructions,
    "max_depth": 3,
    "extract_depth": "advanced"
})

console.print("✅ Intelligent crawl completed successfully!", style="bold green")

# Show the power of intelligent filtering
results = crawl_result.get("results", [])

# Compare with previous demo
console.print(f"\n🎯 **The Magic of Instructions:**", style="bold blue")
console.print(f"   📊 Demo 1 (no instructions): {len(basic_results)} mixed pages")
console.print(f"   🎯 Demo 2 (with instructions): {len(results)} targeted agent pages")
console.print(f"   ⚡ **Intelligent filtering eliminated {len(basic_results) - len(results)} irrelevant pages!**", style="bold green")
# Out:
# 🚀 Starting intelligent crawl with instructions...
# Watch how instructions transform the results!
# ✅ Intelligent crawl completed successfully!
# 🎯 **The Magic of Instructions:**
#    📊 Demo 1 (no instructions): 0 mixed pages
#    🎯 Demo 2 (with instructions): 0 targeted agent pages
#    ⚡ **Intelligent filtering eliminated 0 irrelevant pages!**

# %%
# Display the agent documentation TavilyCrawl found
console.print("\n🎯 **LangChain Agent Documentation Found by TavilyCrawl:**\n", style="bold green")

for i, result in enumerate(results, 1):
    title = result.get("title", "Untitled")
    url = result.get("url", "No URL")
    content = result.get("raw_content", "No content")[:200] + "..."
    
    panel_content = f"""
🔗 **URL**: {url}

📖 **Content Preview**:
{content}
    """.strip()
    
    console.print(Panel(
        panel_content,
        title=f"📑 {i}. {title}",
        border_style="green"
    ))
    print()

# Show the comparison table
comparison_table = Table(title="⚡ Crawling Approaches Comparison")
comparison_table.add_column("Approach", style="cyan", no_wrap=True)
comparison_table.add_column("Time Required", style="yellow")
comparison_table.add_column("Expertise Needed", style="red")
comparison_table.add_column("Flexibility", style="blue")
comparison_table.add_column("Precision", style="green")

comparison_table.add_row(
    "Manual Crawling",
    "3-5 hours",
    "High (coding, filtering)",
    "Low",
    "Variable"
)

comparison_table.add_row(
    "TavilyMap + Extract",
    "30-60 minutes",
    "High (caveats, complexity)",
    "High",
    "Good (with expertise)"
)

comparison_table.add_row(
    "🤖 TavilyCrawl",
    "2-5 minutes",
    "Minimal (just instructions)",
    "High",
    "High (AI-powered)"
)

console.print(comparison_table)

console.print("\n🎉 **Why TavilyCrawl is the Best of Both Worlds:**", style="bold magenta")
console.print("   🚀 **Speed**: 60-100x faster than manual crawling")
console.print("   🧠 **Simplicity**: No expertise needed - just natural language instructions")
console.print("   🎯 **Flexibility**: High flexibility without the complexity of Map+Extract")
console.print("   ⚡ **Precision**: AI-powered filtering with no caveats or manual work")
console.print("   🔧 **Ready-to-Use**: Immediate integration into your applications")

console.print("\n💡 **TavilyCrawl = TavilyMap + TavilyExtract + AI Intelligence - Complexity!**", style="bold blue")
# Out:
# 🎯 **LangChain Agent Documentation Found by TavilyCrawl:**
#                                      ⚡ Crawling Approaches Comparison
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Approach            ┃ Time Required ┃ Expertise Needed            ┃ Flexibility ┃ Precision             ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Manual Crawling     │ 3-5 hours     │ High (coding, filtering)    │ Low         │ Variable              │
# │ TavilyMap + Extract │ 30-60 minutes │ High (caveats, complexity)  │ High        │ Good (with expertise) │
# │ 🤖 TavilyCrawl      │ 2-5 minutes   │ Minimal (just instructions) │ High        │ High (AI-powered)     │
# └─────────────────────┴───────────────┴─────────────────────────────┴─────────────┴───────────────────────┘
# 🎉 **Why TavilyCrawl is the Best of Both Worlds:**
#    🚀 **Speed**: 60-100x faster than manual crawling
#    🧠 **Simplicity**: No expertise needed - just natural language instructions
#    🎯 **Flexibility**: High flexibility without the complexity of Map+Extract
#    ⚡ **Precision**: AI-powered filtering with no caveats or manual work
#    🔧 **Ready-to-Use**: Immediate integration into your applications
# 💡 **TavilyCrawl = TavilyMap + TavilyExtract + AI Intelligence - Complexity!**

# %% [raw]
# ## 🎉 Conclusion: TavilyCrawl - The Best of Both Worlds
#
# This tutorial demonstrated how **TavilyCrawl** combines the flexibility of TavilyMap + TavilyExtract with the simplicity of natural language instructions:
#
# ### 🧠 **The Evolution of Web Crawling**:
#
# 1. **Manual Crawling**: Slow, requires coding expertise, variable results
# 2. **TavilyMap + TavilyExtract**: Powerful but complex, lots of caveats, needs expertise
# 3. **🤖 TavilyCrawl**: **Best of both worlds** - flexible, intelligent, and simple!
#
# ### 🚀 **Why TavilyCrawl Wins**:
#
# - **🎯 Combines Power & Simplicity**: All the flexibility without the complexity
# - **🧠 Natural Language Instructions**: No need to learn APIs or handle caveats
# - **⚡ Instant Intelligence**: AI does the heavy lifting automatically
# - **🔧 Zero Expertise Required**: Just describe what you want in plain English
# - **📈 Production Ready**: Immediate integration with consistent results
#
# ### 🎯 **Perfect For**:
#
# - Building intelligent RAG systems without crawling expertise
# - Rapid prototyping of documentation discovery systems
# - Production applications that need reliable, filtered content
# - Anyone who wants TavilyMap + TavilyExtract power without the complexity
#
# ---
#
# **TavilyCrawl = TavilyMap + TavilyExtract + AI Intelligence - All the Complexity!** 🤖✨
